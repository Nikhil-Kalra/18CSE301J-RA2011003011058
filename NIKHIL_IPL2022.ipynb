# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil-Kalra/18CSE301J-RA2011003011058/blob/main/NIKHIL_IPL2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import plotly.express as px

# %%
df = pd.read_excel("ipl2022 dataset.xlsx", index_col=0)

# %%
df.head()
# Out:
#             Player  Base Price         TYPE  COST IN â‚¹ (CR.) 2021 Squad  \
# 0      Rashid Khan  Draft Pick       BOWLER               15.0        SRH
# 1    Hardik Pandya  Draft Pick  ALL-ROUNDER               15.0         MI
# 2  Lockie Ferguson        2 Cr       BOWLER               10.0        KKR
# 3    Rahul Tewatia     40 Lakh  ALL-ROUNDER                9.0         RR
# 4     Shubman Gill  Draft Pick       BATTER                8.0        KKR
#
#              Team
# 0  Gujarat Titans
# 1  Gujarat Titans
# 2  Gujarat Titans
# 3  Gujarat Titans
# 4  Gujarat Titans

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237 entries, 0 to 236
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Player             237 non-null    object
#  1   Base Price         237 non-null    object
#  2   TYPE               237 non-null    object
#  3   COST IN â‚¹ (CR.)  237 non-null    float64
#  4   2021 Squad         159 non-null    object
#  5   Team               237 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 13.0+ KB

# %%
dfg = df.groupby("Team", as_index=False).agg({
    "COST IN â‚¹ (CR.)": "sum",
})

# %%
dfg
# Out:
#                           Team  COST IN â‚¹ (CR.)
# 0          Chennai Super Kings              87.05
# 1               Delhi Capitals              86.40
# 2               Gujarat Titans              89.65
# 3        Kolkata Knight Riders              81.55
# 4         Lucknow Super Giants              89.40
# 5               Mumbai Indians              89.90
# 6                 Punjab Kings              84.55
# 7             Rajasthan Royals              89.05
# 8  Royal Challengers Bangalore              88.45
# 9          Sunrisers Hyderabad              89.90

# %%
fig = px.pie(df, values='COST IN â‚¹ (CR.)', names='Team', title='Share of Money Spent By Each Team in IPL 2022')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df["TYPE"].value_counts()
# Out:
# ALL-ROUNDER     88
# BOWLER          77
# BATTER          45
# WICKETKEEPER    27
# Name: TYPE, dtype: int64

# %%
dfg1 = df.groupby(["Team","TYPE"], as_index=False).size()

# %%
dfg1
# Out:
#                            Team          TYPE  size
# 0           Chennai Super Kings   ALL-ROUNDER     9
# 1           Chennai Super Kings        BATTER     5
# 2           Chennai Super Kings        BOWLER     8
# 3           Chennai Super Kings  WICKETKEEPER     3
# 4                Delhi Capitals   ALL-ROUNDER     9
# 5                Delhi Capitals        BATTER     5
# 6                Delhi Capitals        BOWLER     7
# 7                Delhi Capitals  WICKETKEEPER     3
# 8                Gujarat Titans   ALL-ROUNDER     8
# 9                Gujarat Titans        BATTER     4
# 10               Gujarat Titans        BOWLER     8
# 11               Gujarat Titans  WICKETKEEPER     2
# 12        Kolkata Knight Riders   ALL-ROUNDER    10
# 13        Kolkata Knight Riders        BATTER     7
# 14        Kolkata Knight Riders        BOWLER     5
# 15        Kolkata Knight Riders  WICKETKEEPER     3
# 16         Lucknow Super Giants   ALL-ROUNDER     9
# ...

# %%
csk = dfg1[dfg1.Team == "Chennai Super Kings"]
dc = dfg1[dfg1.Team == "Delhi Capitals"]
gt = dfg1[dfg1.Team == "Gujarat Titans"]
kkr = dfg1[dfg1.Team == "Kolkata Knight Riders"]
lcg = dfg1[dfg1.Team == "Lucknow Super Giants"]
mi = dfg1[dfg1.Team == "Mumbai Indians"]
pk = dfg1[dfg1.Team == "Punjab Kings"]
rr = dfg1[dfg1.Team == "Rajasthan Royals"]
rcb = dfg1[dfg1.Team == "Royal Challengers Bangalore"]
sh = dfg1[dfg1.Team == "Sunrisers Hyderabad"]

# %%
fig = px.pie(csk, values='size', names='TYPE', title='Type of New Players Bought By CSK in IPL 2022')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(dc, values='size', names='TYPE', title='Type of New Players Bought By DC in IPL 2022')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(gt, values='size', names='TYPE', title='Type of New Players Bought By GT in IPL 2022')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(kkr, values='size', names='TYPE', title='Type of New Players Bought By KKR in IPL 2022')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(lcg, values='size', names='TYPE', title='Type of New Players Bought By LCG in IPL 2022')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(mi, values='size', names='TYPE', title='Type of New Players Bought By MI in IPL 2022')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(pk, values='size', names='TYPE', title='Type of New Players Bought By PK in IPL 2022')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(rr, values='size', names='TYPE', title='Type of New Players Bought By RR in IPL 2022')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(rcb, values='size', names='TYPE', title='Type of New Players Bought By RCB in IPL 2022')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(sh, values='size', names='TYPE', title='Type of New Players Bought By SH in IPL 2022')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
