# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil-Kalra/18CSE301J-RA2011003011058/blob/main/food_sales_nikhil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_excel('/Restaurant food consumption.xlsx')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ee996f1c080f> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel('/Restaurant food consumption.xlsx')
#       4 df.head()
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.info()

# %%
df.set_index('Date_time',inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-010cebe21493> in <cell line: 1>()
# ----> 1 df.set_index('Date_time',inplace=True)
#       2 df.head()
#
# NameError: name 'df' is not defined

# %%
#df['year']=df.index.year
#df['month']=df.index.month
df['day']=df.index.day
#df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d84a1afff95f> in <cell line: 3>()
#       1 #df['year']=df.index.year
#       2 #df['month']=df.index.month
# ----> 3 df['day']=df.index.day
#       4 #df.head()
#
# NameError: name 'df' is not defined

# %%
# group the data by menu category
grouped = df.groupby('MenuCateogry')

# create a scatter plot for each menu category
figs = []
for menu_category, group in grouped:
    fig = px.scatter(group, x=group.index, y='ItemQty', 
                     color='MenuItem', size='ItemPrice', 
                     title=f'Sales of {menu_category} over Time')
    fig.update_xaxes(title_text='Date')
    fig.update_yaxes(title_text='Item Quantity')
    figs.append(fig)

# display the plots
for fig in figs:
    fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a98db6c6a592> in <cell line: 2>()
#       1 # group the data by menu category
# ----> 2 grouped = df.groupby('MenuCateogry')
#       3
#       4 # create a scatter plot for each menu category
#       5 figs = []
#
# NameError: name 'df' is not defined

# %%
# group the data by menu category and sum the ItemQty column
grouped = df.groupby('MenuCateogry')['ItemQty'].sum().reset_index()

# %%
# create a bar chart for the total number of items sold for each menu category
fig = px.bar(grouped, x='MenuCateogry', y='ItemQty',
             color='MenuCateogry', # add color based on menu category
             title='Total Number of Items Sold by Menu Category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# create a box plot for the distribution of prices for each menu category
fig = px.box(df, x='MenuCateogry', y='ItemPrice', 
             color='MenuCateogry', # add color based on menu category
             title='Distribution of Prices by Menu Category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grouped = df.groupby('MenuCateogry')

# create a scatter plot for each menu category
figs = []
for menu_category, group in grouped:
    fig = px.scatter(group, x=group.index, y='ItemQty', 
                     color='MenuItem', size='ItemPrice', 
                     title=f'Sales of {menu_category} over Time',
                     animation_frame='day', # specify the column to animate by
                     range_x=[df.index.min(), df.index.max()], # set the x-axis range
                     range_y=[0, df['ItemQty'].max()] # set the y-axis range
                    )
    fig.update_xaxes(title_text='Date')
    fig.update_yaxes(title_text='Item Quantity')
    figs.append(fig)

# display the plots
for fig in figs:
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
